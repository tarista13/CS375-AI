# %% [markdown]
# # Jupyter Notebook Warmup
#
# The instructions for this Fundamentals notebook are found on the Lab 1 instructions page. (In general the instructions will be within the notebook itself.)

# %%
1+1
# Out:
# 2

# %% [markdown]
# Here is some Markdown formatting:
# * This is **bold**.
# * This is *italic*
# * This is a [link to Calvin's website](https://calvin.edu/)

# %% [markdown]
# If a cell was to have multiple expressions in it, like the example given in the lab instructions, the string "something" and 4.0 would be displayed from the notebook cell. A general rule for what outputs get displayed is the most recent expression that was typed, in this case, x * 2
